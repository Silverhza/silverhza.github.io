# %% [markdown]
# # <center>Final Project (Part 3.1)</center>
# ### <center>Group 50</center>
# ### <center>Zian He, Junsong yao</center>
# <center>2022/11/15</center>

# %% [markdown]
# ## 1. Load & process data

# %%
# import all the packages I need
import pandas as pd
import numpy as np
import altair as alt
import matplotlib.pyplot as plt

# %%
myJekyllSaveDir = '/Users/silver/Downloads/'

# %%
data_url = 'https://data.illinois.gov/dataset/3bfc782a-baae-43ea-a29a-214fb1cb725e/resource/b23aa1b9-c0e0-4779-ba7a-6ca8b7b1df1c/download/cm_offense_archive.csv'
data = pd.read_csv(data_url)
data.columns
# Out:
# Index(['CaseNo', 'Description', 'Occurred Date', 'Occurred Day of Week',
#        'Occurred Time', 'X', 'Y', 'Crime Against Code', 'Crime Against',
#        'Group', 'Beat', 'Ward'],
#       dtype='object')

# %%
data
# Out:
#            CaseNo                                     Description  \
# 0       16-009615                        90C - Disorderly Conduct
# 1       16-014351                        90C - Disorderly Conduct
# 2       16-016247                            13B - Simple Assault
# 3       16-016181  290 - Destruction/Damage/Vandalism of Property
# 4       16-023111                         23H - All Other Larceny
# ...           ...                                             ...
# 200638  20-087026                        90C - Disorderly Conduct
# 200639  20-086961                               23C - Shoplifting
# 200640  20-087240  290 - Destruction/Damage/Vandalism of Property
# 200641  20-087240                        13A - Aggravated Assault
# 200642  20-087212                        90C - Disorderly Conduct
#
#         Occurred Date  Occurred Day of Week  Occurred Time          X  \
# 0            20160125                     1           1006 -89.124354
# 1            20160205                     5           1906 -89.070417
# 2            20160209                     2           1550 -89.042083
# 3            20160210                     3           1138 -89.029085
# 4            20160206                     6            100 -89.029201
# ...               ...                   ...            ...        ...
# 200638       20200807                     5           1430 -89.131835
# 200639       20200807                     5           1241 -89.086349
# 200640       20200807                     5           2318 -88.966168
# 200641       20200807                     5           2318 -88.966168
# 200642       20200807                     5           2145 -89.063908
#
#                 Y Crime Against Code Crime Against Group  Beat  Ward
# 0       42.284104                NaN           NaN   NaN   NaN   7.0
# 1       42.254735                NaN           NaN   NaN   NaN  11.0
# 2       42.238147                NaN           NaN   NaN   NaN   8.0
# 3       42.241433                NaN           NaN   NaN   NaN  14.0
# 4       42.211097                NaN           NaN   NaN   NaN  14.0
# ...           ...                ...           ...   ...   ...   ...
# 200638  42.276667                 SO       SOCIETY     B  RP04  13.0
# 200639  42.250115                 PR      PROPERTY     A  RP06  11.0
# 200640  42.273391                 PR      PROPERTY     A  RP10   1.0
# 200641  42.273391                 PE        PERSON     A  RP10   1.0
# 200642  42.221579                 SO       SOCIETY     B  RP07   6.0
#
# [200643 rows x 12 columns]

# %%
data.head()
# Out:
#       CaseNo                                     Description  Occurred Date  \
# 0  16-009615                        90C - Disorderly Conduct       20160125
# 1  16-014351                        90C - Disorderly Conduct       20160205
# 2  16-016247                            13B - Simple Assault       20160209
# 3  16-016181  290 - Destruction/Damage/Vandalism of Property       20160210
# 4  16-023111                         23H - All Other Larceny       20160206
#
#    Occurred Day of Week  Occurred Time          X          Y  \
# 0                     1           1006 -89.124354  42.284104
# 1                     5           1906 -89.070417  42.254735
# 2                     2           1550 -89.042083  42.238147
# 3                     3           1138 -89.029085  42.241433
# 4                     6            100 -89.029201  42.211097
#
#   Crime Against Code Crime Against Group Beat  Ward
# 0                NaN           NaN   NaN  NaN   7.0
# 1                NaN           NaN   NaN  NaN  11.0
# 2                NaN           NaN   NaN  NaN   8.0
# 3                NaN           NaN   NaN  NaN  14.0
# 4                NaN           NaN   NaN  NaN  14.0

# %%
crime_data = data[(data["Crime Against"]=='SOCIETY')|(data["Crime Against"]=='PROPERTY')|(data["Crime Against"]=='PERSON')]

# %%
crime_data["Crime Against"]
# Out:
# 20        PROPERTY
# 34        PROPERTY
# 51        PROPERTY
# 52          PERSON
# 53          PERSON
#             ...
# 200638     SOCIETY
# 200639    PROPERTY
# 200640    PROPERTY
# 200641      PERSON
# 200642     SOCIETY
# Name: Crime Against, Length: 200594, dtype: object

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ## 2. Create dashboard

# %% [markdown]
# ```python
# brush = alt.selection_interval(encodings=['x','y'])
#
# rect_alt = alt.Chart(crime_data).mark_rect().encode(
#     alt.X("Crime Against:O"),
#     alt.Y("Occurred Day of Week:O"),
#     alt.Color("count()")
# ).properties(
#     height=400
# ).add_selection(
#     brush
# )
#
# hist_alt = alt.Chart(crime_data).mark_bar().encode(
#     alt.X("Occurred Time:Q",bin=True, axis=alt.Axis(title='Occurred Time')),
#     alt.Y("count()", axis=alt.Axis(title='Frequency'))
# ).transform_filter(
#     brush
# )
#
# dashboard_local = rect_alt.properties(width=150,height=300) | hist_alt.properties(width=150)
# dashboard_local.save(myJekyllSaveDir+'Final3.1.json')
# ```

# %% [markdown]
# ## 3.1 Dashboard describe

# %% [markdown]
# We created a visualization of the average number of wards of different types of crime objects for each day of the week in this city. As well as the distribution of the time of occurrence of different crime objects for each day of the week. We first created a heatmap with the x-axis of the visualization being the three types of crime objects (Person, Property, Society) and the y-axis being each day of the week. The color of the heatmap then represents the difference in the average number of victims. We link this heatmap to a bar chart. This allows us to see the number of different crime times occurring at that average ward number by selecting a different average ward number. This dashboard allows the layperson to understand the average number of wards, or victims, for each day of the week, what type of crimes these victims were subjected to, as well as the distribution of when these crimes occurred.

# %% [markdown]
# ## 3.2 Contextual datasets

# %% [markdown]
# Police Arrests Upload Datasets: https://data.illinois.gov/dataset/1d18ecc0-3c7e-4507-b8cc-7a5e30359d44/resource/ca1dceb3-01f8-4a56-935b-7e3035ff60a4/download/police-arrests-upload_20191226.csv

# %% [markdown]
# The contextual data we found were police arrest data for Urbana. This data has the same clear documentation of crimes in Urbana as the City of Rockford crime records that we used. And we found some very interesting elements in this data, such as the age, gender, and race of the arrestees. We think these variables can help us to analyze and predict the motives and trends of crime by combining or comparing the two data visualizations.
#
# Because the entire police arrest data volume is very large, we chose to just use a data volume of 1000. Next, we created three contextual visualizations. The first graph is a histogram with the x-axis representing the age of the arrestees and the y-axis representing the number of arrestees of each age. And we categorized the race of the arrestees by color into Asian, Black, White, Hispanic, and Unknown. We can see the number of arrestees by looking at the length of each color in the bar. As you can see from this graph, the 20-25 age group has the highest number of arrests. White has the highest number of arrests in this age group. The second and third graphs of our second dashboard. the point plots above, the x-axis represents the reason the offender was arrested. the y-axis represents the method of the arrest. We have also divided each point into different racial groups by color. The bar chart below visualizes the number of arrests for each race. The x-axis represents the number of arrests and the y-axis represents the race of arrests. We can select the point in the dot plot by swiping the area with the mouse to see how the number of arrests for each race changes in comparison. We find that on-view arrests are the most common type of arrest, while warrant arrests are the least common type of arrest. We also find that the more serious arrests, such as warrant arrest or detention, have more blacks in them. The less severe types of arrests, such as summons, have more whites.

# %%
d_url = 'https://data.illinois.gov/dataset/1d18ecc0-3c7e-4507-b8cc-7a5e30359d44/resource/ca1dceb3-01f8-4a56-935b-7e3035ff60a4/download/police-arrests-upload_20191226.csv'
df = pd.read_csv(d_url)

# %%
small_df = df.sample(n=1000)
small_df
# Out:
#        arrest_code incident_number date_of_arrest  year_of_arrest  \
# 60574    A10-04289       U10-04657     08/23/2010            2010
# 120587   A11-01246       U11-01527     03/22/2011            2011
# 67319    A12-02167       T12-02167     05/03/2012            2012
# 164294   A19-00152       U19-00141     01/10/2019            2019
# 190492   A92-01003       U92-00999     02/22/1992            1992
# ...            ...             ...            ...             ...
# 135137   A91-06108       U91-06255     11/21/1991            1991
# 27026    A03-04372       U03-04340     07/13/2003            2003
# 29525    A04-05551       T04-05549     09/21/2004            2004
# 135341   A17-03360       U17-04240     08/23/2017            2017
# 162425   A90-06279       U90-06242     11/16/1990            1990
#
#         month_of_arrest arrest_type_description  crime_code  \
# 60574                 8                SUMMONED        6621
# 120587                3                 ON VIEW        6628
# 67319                 5                SUMMONED        6625
# 164294                1          WARRANT ARREST        5081
# 190492                2                     NaN        4387
# ...                 ...                     ...         ...
# 135137               11                     NaN        6616
# 27026                 7                SUMMONED        6608
# 29525                 9                SUMMONED        6614
# 135341                8                 ON VIEW        2890
# 162425               11                     NaN        2480
#
#                   crime_code_description crime_category_code  \
# 60574            FAILURE TO REDUCE SPEED                 C28
# 120587                  IMPROPER BACKING                 C28
# 67319             LOUD STEREO IN VEHICLE                 C28
# 164294                  WARRANT-IN STATE                 C86
# 190492        VIOLATION ORDER PROTECTION                 C85
# ...                                  ...                 ...
# 135137  FAILURE TO YIELD AT INTERSECTION                 C28
# 27026                IMPROPER LANE USAGE                 C28
# 29525                  FAILURE TO SIGNAL                 C28
# 135341      DISORDERLY CONDUCT-ALL OTHER                 C30
# 162425   SUSPEND REVOKED DRIVERS LICENSE                 C28
#
#            crime_category_description  ... age_at_arrest arrestee_sex  \
# 60574                Traffic Offenses  ...          29.0         MALE
# 120587               Traffic Offenses  ...          22.0       FEMALE
# 67319                Traffic Offenses  ...          38.0       FEMALE
# 164294             Warrants & Summons  ...          21.0       FEMALE
# 190492  Violation Ord Protect/No Cont  ...          28.0         MALE
# ...                               ...  ...           ...          ...
# 135137               Traffic Offenses  ...          21.0         MALE
# 27026                Traffic Offenses  ...          20.0       FEMALE
# 29525                Traffic Offenses  ...          23.0         MALE
# 135341             Disorderly Conduct  ...          61.0       FEMALE
# 162425               Traffic Offenses  ...          24.0         MALE
#
#        arrestee_race  arrestee_employment_description  \
# 60574          WHITE                          UNKNOWN
# 120587         BLACK                          UNKNOWN
# 67319          BLACK                          UNKNOWN
# 164294      HISPANIC                          UNKNOWN
# 190492         WHITE                              NaN
# ...              ...                              ...
# 135137         WHITE                              NaN
# 27026          WHITE                          UNKNOWN
# 29525          BLACK                          UNKNOWN
# 135341         BLACK                          UNKNOWN
# 162425         BLACK                              NaN
#
#        arrestee_residency_description  arrestee_home_city arrestee_home_state  \
# 60574                    NON-RESIDENT              URBANA                  IL
# 120587                        UNKNOWN              URBANA                  IL
# 67319                        RESIDENT            KANKAKEE                  IL
# 164294                       RESIDENT              URBANA                  IL
# 190492                            NaN          RICHARDSON                  TX
# ...                               ...                 ...                 ...
# 135137                            NaN           CHAMPAIGN                  IL
# 27026                    NON-RESIDENT           CHAMPAIGN                  IL
# 29525                    NON-RESIDENT              URBANA                  IL
# 135341                        UNKNOWN                 NaN                 NaN
# 162425                            NaN                 NaN                 NaN
#
#        arrestee_home_zip arrest_resolution  mapped_address
# 60574              61801        BONDED OUT      URBANA, IL
# 120587             61801     TAKEN TO JAIL      URBANA, IL
# 67319              60901   INDIVIDUAL BOND    KANKAKEE, IL
# 164294             61801     TAKEN TO JAIL      URBANA, IL
# 190492             00000     TAKEN TO JAIL  RICHARDSON, TX
# ...                  ...               ...             ...
# 135137             61820   INDIVIDUAL BOND   CHAMPAIGN, IL
# 27026              61820   INDIVIDUAL BOND   CHAMPAIGN, IL
# 29525              61801        BONDED OUT      URBANA, IL
# 135341             00000     TAKEN TO JAIL             NaN
# 162425             00000     TAKEN TO JAIL             NaN
#
# [1000 rows x 25 columns]

# %%
contextual1 = alt.Chart(small_df).mark_bar().encode(x=alt.X('age_at_arrest', bin=alt.Bin(maxbins=30)),y='count()',color='arrestee_race')
contextual1.save(myJekyllSaveDir+'contextual1.json')
contextual1
# Out:
# alt.Chart(...)

# %%
brush = alt.selection(type='interval')

points = alt.Chart(small_df).mark_point().encode(
    x='crime_category_description',
    y='arrest_type_description',
    color=alt.condition(brush, 'arrestee_race', alt.value('lightgray'))
).add_selection(
    brush
).properties(
   height=150, width=300
)

bars = alt.Chart(small_df).mark_bar().encode(
    y='arrestee_race',
    color='arrestee_race',
    x='count(arrestee_race)'
).transform_filter(
    brush
).properties(
   height=100, width=300
)

contextual2 = points & bars
contextual2.save(myJekyllSaveDir+'contextual2.json')
contextual2
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ## 4. Conclusion

# %% [markdown]
# By visualizing the two dashboards and a graph, we found that the most frequent crimes in the city are crimes against property and occur most often on Mondays and Fridays. Crimes against individuals are concentrated on Saturdays and Sundays, while crimes against society are more evenly distributed. The age of the offenders is between 20 and 25, with whites being the most numerous, followed by blacks. And blacks were more often arrested for felonies, while whites were more often arrested for misdemeanors. We believe that through these visualization graphs we can effectively analyze and predict the crime trends in the city.
